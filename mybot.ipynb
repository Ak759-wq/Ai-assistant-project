# %%
import ollama

# %%
response = ollama.chat(model='mistral', messages=[{'role':'user', 'content':'what is LLM?'}])
print(response['message']['content'])
# Out:
#  LLM stands for Master of Laws, which is an advanced postgraduate academic degree pursued by those holding a professional law degree (usually a Bachelor of Laws or Juris Doctor) and who wish to specialize in a particular area of law. This degree is recognized worldwide and can help lawyers gain expertise in areas such as international law, tax law, intellectual property law, human rights law, environmental law, among others. The duration of an LLM program varies but typically takes one year for full-time study.

# %%
user_input = input("Ask a question...")
response = ollama.chat(model='mistral', messages=[{'role':'user', 'content':user_input}])
print(response['message']['content'])

# %%
def ask_ai(question):
    response = ollama.chat(model='mistral', messages=[{'role':'user', 'content':question}])
    return response['message']['content']
